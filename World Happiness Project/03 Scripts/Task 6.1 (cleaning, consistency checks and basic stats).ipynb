# %% [markdown]
# # 01 Importing Libraries and Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Assigning a path
path = r'/Users/dramblys/Desktop/Achievement 6/World Happiness Project'

# %%
# Import Data
df_whp=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'WHP.csv'))

# %% [markdown]
# # 02 Checking Data Consistency

# %%
# find number of rows
df_whp.shape
# Out:
# (2089, 12)

# %%
df_whp.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2089.000000  2089.000000         2062.000000     2076.000000
# mean   2013.727621     5.473747            9.378408        0.811542
# std       4.455614     1.115567            1.143520        0.118935
# min    2005.000000     2.178809            5.526723        0.290184
# 25%    2010.000000     4.651972            8.473547        0.747664
# 50%    2014.000000     5.405246            9.463269        0.834770
# 75%    2017.000000     6.294282           10.347656        0.904682
# max    2021.000000     8.018934           11.665803        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2031.000000                   2057.000000
# mean                          63.180326                      0.745462
# std                            6.948546                      0.140751
# min                            6.720000                      0.257534
# ...

# %% [markdown]
# Based on count - there are some missing values; in some columns more than others. Not sure why there would be negative numbers (Generosity)? Life expectancy min at 6.7Y is questionable.

# %%
# Check negative Generosity scores
df_whp.loc[df_whp['Generosity'] < 0]
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 9     Afghanistan  2017     2.661718            7.629684        0.490880
# 10    Afghanistan  2018     2.694303            7.617663        0.507516
# 11    Afghanistan  2019     2.375092            7.632903        0.419973
# 13        Albania  2007     4.634252            9.121524        0.821372
# 14        Albania  2009     5.485470            9.241250        0.833047
# ...           ...   ...          ...                 ...             ...
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# Over half of rows have negative numbers of Generosity. Will have to research why/how calculated...

# %%
# Check low life expectancy scores
df_whp.loc[df_whp['Healthy life expectancy at birth'] < 40]
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 721        Haiti  2006     3.754156            7.964181        0.693801
# 722        Haiti  2008     3.846329            8.004622        0.679098
# 723        Haiti  2010     3.765999            7.972780        0.554031
# 724        Haiti  2011     4.844574            8.007442        0.567039
# 725        Haiti  2012     4.413475            7.997653        0.748663
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 721                          6.720000                      0.449475
# 722                         17.360001                      0.464971
# 723                         28.000000                      0.372941
# 724                         33.320000                      0.412588
# 725                         38.639999                      0.482486
#
#      Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
# check for mixed type columns 
for col in df_whp.columns.tolist():
  weird = (df_whp[[col]].applymap(type) != df_whp[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_whp[weird]) > 0:
    print (col)

# %%
# check for missing values 
df_whp.isnull().sum()
# Out:
# Country name                           0
# year                                   0
# Life Ladder                            0
# Log GDP per capita                    27
# Social support                        13
# Healthy life expectancy at birth      58
# Freedom to make life choices          32
# Generosity                            80
# Perceptions of corruption            113
# Positive affect                       24
# Negative affect                       16
# Confidence in national government    216
# dtype: int64

# %% [markdown]
# Some of the data for some of the countries is not available. Mostly Perception of corruption and Confidence in government. There is no way to impute it and makes no sense to delete, so i am leaving it as is.

# %%
# find duplicates
df_dups = df_whp[df_whp.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Country name, year, Life Ladder, Log GDP per capita, Social support, Healthy life expectancy at birth, Freedom to make life choices, Generosity, Perceptions of corruption, Positive affect, Negative affect, Confidence in national government]
# Index: []

# %%
# Check counts
df_whp['year'].value_counts(dropna = False)
# Out:
# 2017    147
# 2011    146
# 2014    145
# 2019    144
# 2015    143
# 2016    142
# 2012    142
# 2018    142
# 2013    137
# 2010    124
# 2021    119
# 2020    116
# 2009    114
# 2008    110
# 2007    102
# 2006     89
# 2005     27
# Name: year, dtype: int64

# %%
# Check counts
df_whp['Country name'].value_counts(dropna = False)
# Out:
# Zimbabwe        16
# Tanzania        16
# Indonesia       16
# India           16
# South Africa    16
#                 ..
# Suriname         1
# Guyana           1
# Maldives         1
# Cuba             1
# Oman             1
# Name: Country name, Length: 166, dtype: int64

# %%
# Check data types
df_whp.dtypes
# Out:
# Country name                          object
# year                                   int64
# Life Ladder                          float64
# Log GDP per capita                   float64
# Social support                       float64
# Healthy life expectancy at birth     float64
# Freedom to make life choices         float64
# Generosity                           float64
# Perceptions of corruption            float64
# Positive affect                      float64
# Negative affect                      float64
# Confidence in national government    float64
# dtype: object
